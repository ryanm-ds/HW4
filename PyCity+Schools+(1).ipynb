# %%
import pandas as pd
import numpy as np

# %%
schools_df = pd.read_csv('schools_complete.csv')
students_df = pd.read_csv('students_complete.csv')

# %%
schools_df.head()
# Out:
#    School ID            school_name      type  size   budget
# 0          0      Huang High School  District  2917  1910635
# 1          1   Figueroa High School  District  2949  1884411
# 2          2    Shelton High School   Charter  1761  1056600
# 3          3  Hernandez High School  District  4635  3022020
# 4          4    Griffin High School   Charter  1468   917500

# %%
students_df.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score
# 0             66          79
# 1             94          61
# 2             90          60
# 3             67          58
# 4             97          84

# %%
schoolinfo_df =pd.merge(schools_df,students_df,how='outer',on=['school_name'])

# %%
schoolinfo_df.head()
# Out:
#    School ID        school_name      type  size   budget  Student ID  \
# 0          0  Huang High School  District  2917  1910635           0
# 1          0  Huang High School  District  2917  1910635           1
# 2          0  Huang High School  District  2917  1910635           2
# 3          0  Huang High School  District  2917  1910635           3
# 4          0  Huang High School  District  2917  1910635           4
#
#         student_name gender grade  reading_score  math_score
# 0       Paul Bradley      M   9th             66          79
# 1       Victor Smith      M  12th             94          61
# 2    Kevin Rodriguez      M  12th             90          60
# 3  Dr. Richard Scott      M  12th             67          58
# 4         Bonnie Ray      F   9th             97          84

# %%
num_schools = schoolinfo_df['school_name'].nunique()

# %%
num_students = schoolinfo_df['Student ID'].count()

# %%
schoolinfo_df.shape
# Out:
# (39170, 11)

# %%
schoolinfo_df.describe()
# Out:
#           School ID          size        budget    Student ID  reading_score  \
# count  39170.000000  39170.000000  3.917000e+04  39170.000000    39170.00000
# mean       6.978172   3332.957110  2.117241e+06  19584.500000       81.87784
# std        4.444329   1323.914069  8.749987e+05  11307.549359       10.23958
# min        0.000000    427.000000  2.480870e+05      0.000000       63.00000
# 25%        3.000000   1858.000000  1.081356e+06   9792.250000       73.00000
# 50%        7.000000   2949.000000  1.910635e+06  19584.500000       82.00000
# 75%       11.000000   4635.000000  3.022020e+06  29376.750000       91.00000
# max       14.000000   4976.000000  3.124928e+06  39169.000000       99.00000
#
#          math_score
# count  39170.000000
# mean      78.985371
# std       12.309968
# min       55.000000
# 25%       69.000000
# 50%       79.000000
# 75%       89.000000
# max       99.000000

# %%
total_budget = schoolinfo_df['budget'].unique()

# %%
total_budget = total_budget.sum()

# %%
stu_budget = total_budget/num_students

# %%
avg_math = schoolinfo_df['math_score'].mean()

# %%
avg_reading = schoolinfo_df['reading_score'].mean()

# %%
passing = (avg_math+avg_reading)/2

# %%
math_passing = (((schoolinfo_df[schoolinfo_df['math_score']>=70].count())/num_students)*100)[0]

# %%
reading_passing = (((schoolinfo_df[schoolinfo_df['reading_score']>=70].count())/num_students)*100)[0]

# %%
district_summary = pd.DataFrame({"Total Schools": [num_schools],"Total Students":[num_students],"Average Math Score": [avg_math],
                                "Average Reading Score":[avg_reading],"% Passing Math":[math_passing],"% Passing Reading"
                                :[reading_passing],"% Overall Passing Rate":[passing]})

# %%
district_summary
# Out:
#    % Overall Passing Rate  % Passing Math  % Passing Reading  \
# 0               80.431606       74.980853          85.805463
#
#    Average Math Score  Average Reading Score  Total Schools  Total Students
# 0           78.985371               81.87784             15           39170

# %%
schools = []
for schoolname in schools_df['school_name']:
    schools.append(schoolname)

# %%
school_summary = pd.DataFrame(columns=['School','Total Students', 'Total School Budget','Per Student Budget','Average Math Score', 
                                       'Average Reading Score','% Passing Math','% Passing Reading','% Overall Passing Rate'])

# %%
t = schoolinfo_df[schoolinfo_df['school_name']=='Huang High School'][:1]

# %%
t
# Out:
#    School ID        school_name      type  size   budget  Student ID  \
# 0          0  Huang High School  District  2917  1910635           0
#
#    student_name gender grade  reading_score  math_score
# 0  Paul Bradley      M   9th             66          79

# %%
for school in schools:
    
    
    loopdf = schoolinfo_df[schoolinfo_df['school_name']==school]
    school_name = loopdf['school_name'].iloc[0]
    totalstudents = loopdf['Student ID'].count()
    totalbudget = loopdf['budget'].iloc[0]
    perstudent = totalbudget/totalstudents
    avgmath = loopdf['math_score'].mean()
    avgreading = loopdf['reading_score'].mean()
    pct_math = (((loopdf[loopdf['math_score']>=70].count())/totalstudents)*100)[0]
    pct_reading = (((loopdf[loopdf['reading_score']>=70].count())/totalstudents)*100)[0]
    ovr_avg = (pct_math+pct_reading)/2
    
    
    
    school_summary =school_summary.append({'School':school_name,'Total Students':totalstudents, 
                                            'Total School Budget':totalbudget,'Per Student Budget':perstudent,
                                            'Average Math Score':avgmath, 
                                       'Average Reading Score':avgreading,'% Passing Math':pct_math,
                                            '% Passing Reading':pct_reading,'% Overall Passing Rate':ovr_avg},ignore_index=True)

# %%
school_summary.sort_values(['% Overall Passing Rate'],ascending=False)[:5]
# Out:
#                  School Total Students Total School Budget  \
# 6   Cabrera High School           1858             1081356
# 14   Thomas High School           1635             1043130
# 9      Pena High School            962              585858
# 4   Griffin High School           1468              917500
# 5    Wilson High School           2283             1319574
#
#     Per Student Budget  Average Math Score  Average Reading Score  \
# 6                582.0           83.061895              83.975780
# 14               638.0           83.418349              83.848930
# 9                609.0           83.839917              84.044699
# 4                625.0           83.351499              83.816757
# 5                578.0           83.274201              83.989488
#
#     % Passing Math  % Passing Reading  % Overall Passing Rate
# 6        94.133477          97.039828               95.586652
# 14       93.272171          97.308869               95.290520
# ...

# %%
school_summary.sort_values(['% Overall Passing Rate'],ascending=True)[:5]
# Out:
#                    School Total Students Total School Budget  \
# 11  Rodriguez High School           3999             2547363
# 1    Figueroa High School           2949             1884411
# 0       Huang High School           2917             1910635
# 12    Johnson High School           4761             3094650
# 13       Ford High School           2739             1763916
#
#     Per Student Budget  Average Math Score  Average Reading Score  \
# 11               637.0           76.842711              80.744686
# 1                639.0           76.711767              81.158020
# 0                655.0           76.629414              81.182722
# 12               650.0           77.072464              80.966394
# 13               644.0           77.102592              80.746258
#
#     % Passing Math  % Passing Reading  % Overall Passing Rate
# 11       66.366592          80.220055               73.293323
# 1        65.988471          80.739234               73.363852
# ...

# %%
grades_list = ['9th', '10th', '11th', '12th']

# %%
## function to get each high school grade and combine them ##
def high_school_grade_splitter(dataframe, grade_list):
    list_grades = []
    for x in grade_list:
        list_grades.append(pd.Series(dataframe[dataframe['grade']==x].groupby(by='school_name')['math_score'].mean(),
                       name=x))
        
    return pd.concat(list_grades, axis=1)

# %%
combined_math = high_school_grade_splitter(schoolinfo_df, grades_list)

# %%
combined_math
# Out:
#                              9th       10th       11th       12th
# school_name
# Bailey High School     77.083676  76.996772  77.515588  76.492218
# Cabrera High School    83.094697  83.154506  82.765560  83.277487
# Figueroa High School   76.403037  76.539974  76.884344  77.151369
# Ford High School       77.361345  77.672316  76.918058  76.179963
# Griffin High School    82.044010  84.229064  83.842105  83.356164
# Hernandez High School  77.438495  77.337408  77.136029  77.186567
# Holden High School     83.787402  83.429825  85.000000  82.855422
# Huang High School      77.027251  75.908735  76.446602  77.225641
# Johnson High School    77.187857  76.691117  77.491653  76.863248
# Pena High School       83.625455  83.372000  84.328125  84.121547
# Rodriguez High School  76.859966  76.612500  76.395626  77.690748
# Shelton High School    83.420755  82.917411  83.383495  83.778976
# Thomas High School     83.590022  83.087886  83.498795  83.497041
# ...

# %%
def reading_score_grade(dataframe,grades):
    grade_list = []
    for grade in grades:
        grade_list.append(pd.Series(schoolinfo_df[schoolinfo_df['grade']==grade].groupby('school_name')['reading_score']
                                    .mean(),name=grade))
    return pd.concat(grade_list,axis=1)

# %%
readingby_grade = reading_score_grade(schoolinfo_df,grades_list)

# %%
readingby_grade
# Out:
#                              9th       10th       11th       12th
# school_name
# Bailey High School     81.303155  80.907183  80.945643  80.912451
# Cabrera High School    83.676136  84.253219  83.788382  84.287958
# Figueroa High School   81.198598  81.408912  80.640339  81.384863
# Ford High School       80.632653  81.262712  80.403642  80.662338
# Griffin High School    83.369193  83.706897  84.288089  84.013699
# Hernandez High School  80.866860  80.660147  81.396140  80.857143
# Holden High School     83.677165  83.324561  83.815534  84.698795
# Huang High School      81.290284  81.512386  81.417476  80.305983
# Johnson High School    81.260714  80.773431  80.616027  81.227564
# Pena High School       83.807273  83.612000  84.335938  84.591160
# Rodriguez High School  80.993127  80.629808  80.864811  80.376426
# Shelton High School    84.122642  83.441964  84.373786  82.781671
# Thomas High School     83.728850  84.254157  83.585542  83.831361
# ...

# %%
spending_bins = [0, 585, 615, 645, 675]
group_names = ["<$585", "$585-615", "$615-645", "$645-675"]

# %%
school_summary['Student Ranges'] = pd.cut(school_summary['Per Student Budget'],bins=spending_bins,labels=group_names)

# %%
school_summary.head()
# Out:
#                   School Total Students Total School Budget  \
# 0      Huang High School           2917             1910635
# 1   Figueroa High School           2949             1884411
# 2    Shelton High School           1761             1056600
# 3  Hernandez High School           4635             3022020
# 4    Griffin High School           1468              917500
#
#    Per Student Budget  Average Math Score  Average Reading Score  \
# 0               655.0           76.629414              81.182722
# 1               639.0           76.711767              81.158020
# 2               600.0           83.359455              83.725724
# 3               652.0           77.289752              80.934412
# 4               625.0           83.351499              83.816757
#
#    % Passing Math  % Passing Reading  % Overall Passing Rate Student Ranges
# 0       65.683922          81.316421               73.500171       $645-675
# ...

# %%
studentranges = school_summary[['Average Math Score','Average Reading Score','% Passing Math',
               '% Passing Reading','% Overall Passing Rate','Student Ranges']].groupby('Student Ranges').mean()

# %%
studentranges.reindex([group_names])
# Out:
#                 Average Math Score  Average Reading Score  % Passing Math  \
# Student Ranges
# <$585                    83.455399              83.933814       93.460096
# $585-615                 83.599686              83.885211       94.230858
# $615-645                 79.079225              81.891436       75.668212
# $645-675                 76.997210              81.027843       66.164813
#
#                 % Passing Reading  % Overall Passing Rate
# Student Ranges
# <$585                   96.610877               95.035486
# $585-615                95.900287               95.065572
# $615-645                86.106569               80.887391
# $645-675                81.133951               73.649382

# %%
size_bins = [0, 1000, 2000, 5000]
group_names_sizes = ["Small (<1000)", "Medium (1000-2000)", "Large (2000-5000)"]

# %%
school_summary['School Size'] = pd.cut(school_summary['Total Students'],bins=size_bins,labels=group_names_sizes)

# %%
studentranges = school_summary[['Average Math Score','Average Reading Score','% Passing Math',
               '% Passing Reading','% Overall Passing Rate','Student Ranges']].groupby('Student Ranges').mean()

# %%
sizeranges = school_summary[['Average Math Score','Average Reading Score','% Passing Math',
               '% Passing Reading','% Overall Passing Rate','School Size']].groupby('School Size').mean()

# %%
sizeranges.reindex(index=[group_names_sizes])
# Out:
#                     Average Math Score  Average Reading Score  % Passing Math  \
# School Size
# Small (<1000)                83.821598              83.929843       93.550225
# Medium (1000-2000)           83.374684              83.864438       93.599695
# Large (2000-5000)            77.746417              81.344493       69.963361
#
#                     % Passing Reading  % Overall Passing Rate
# School Size
# Small (<1000)               96.099437               94.824831
# Medium (1000-2000)          96.790680               95.195187
# Large (2000-5000)           82.766634               76.364998

# %%
school_type = pd.concat([school_summary,schools_df['type']],axis=1)

# %%
school_type[['Average Math Score','Average Reading Score','% Passing Math',
               '% Passing Reading','% Overall Passing Rate','type']].groupby('type').mean()
# Out:
#           Average Math Score  Average Reading Score  % Passing Math  \
# type
# Charter            83.473852              83.896421       93.620830
# District           76.956733              80.966636       66.548453
#
#           % Passing Reading  % Overall Passing Rate
# type
# Charter           96.586489               95.103660
# District          80.799062               73.673757

# %% [markdown]
# # Two considerations:
# # 1. Charter schools outperform district schools
# # 2. Smaller schools tend to outperform their larger counter parts.
